# %% [markdown]
# <a href="https://colab.research.google.com/github/NiyiRoyce/Inda_AVM/blob/main/Inda_Fmv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Initialization

# %% [markdown]
# Setup & Environment

# %%
# !pip install google-cloud-bigquery google-cloud-bigquery-storage
# !pip install statsmodels lightgbm catboost geopy haversine prophet
# !pip install geopandas shapely
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# Data Loading (Big Query)

# %%
from google.cloud import bigquery

client = bigquery.Client(project="primal-result-478707-k2")

query = """
SELECT *
FROM `primal-result-478707-k2.wed_scrape_sync.master_listings`
LIMIT 10
"""

df = client.query(query).to_dataframe()
print(df.head())
# Out:
#                                      id                       created_at  \
# 0  fff3e66e-3b48-41c2-a430-1f77224e4dd4 2025-12-09 15:21:02.333178+00:00
# 1  f5203f85-0e19-4619-9f7a-98b5373e39c4 2025-12-09 15:09:41.932133+00:00
# 2  60f06684-132c-41e3-9ef0-3f98fad9ef0d 2025-12-09 15:09:41.924745+00:00
# 3  b6d1bd79-291d-43d1-a9b1-a907c8805b7b 2025-12-09 15:09:41.925645+00:00
# 4  85c3473f-1e0a-4618-ba6c-148361500fd1 2025-12-09 15:09:41.928474+00:00
#
#    source_site                                         detail_url  updated_at  \
# 0          NPC  https://www.nigeriapropertycentre.com/for-sale...  2025-11-30
# 1  propertypro  https://propertypro.ng/property/4-bedroom-hous...  2025-12-09
# 2  propertypro  https://propertypro.ng/property/6-bedroom-hous...  2025-12-08
# 3  propertypro  https://propertypro.ng/property/3-bedroom-hous...  2025-12-09
# 4  propertypro  https://propertypro.ng/property/3-bedroom-hous...  2025-12-09
#
# ...

# %% [markdown]
# # Feature Selection and Transformation

# %% [markdown]
# Feature transformations
#
#
# * log(square footage)
# * age polynomial
# * price per sq ft
# * month/year dummies
# * normalized categorical encodings
